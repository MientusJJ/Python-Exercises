# %% [markdown]
# <a href="https://colab.research.google.com/github/MientusJJ/Python-Exercises/blob/main/Kopia_notatnika_Z08_K_rbf_SVM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import metrics

from mlxtend.plotting import plot_decision_regions
from sklearn.svm import SVC

# %% [markdown]
# # RBF SVM Classification

# %%
from sklearn.datasets import make_moons
X, y = make_moons(n_samples=200, noise=.1, random_state=42)

# %%
plt.scatter(X[:, 0], X[:, 1], c=y)
plt.show()

# %% [markdown]
# # Kernel trick
#
# # Zad.
#
# Naucz SVM z jądrem "rbf" o parametrach
#
# * gamma=0.01, C=1.0
# * gamma=0.1, C=1.0
# * gamma=1, C=1.0
# * gamma=10, C=1.0
# * gamma=100, C=1.0
# * gamma=100, C=10
# * gamma=100, C=100

# %%
svm = SVC(kernel='rbf', gamma=0.01, C=1.0)

svm.fit(X, y)
xx, yy = np.meshgrid(np.linspace(-2, 3, 500),
                     np.linspace(-1.5, 2, 500))
Z = svm.decision_function(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)




plt.contourf(xx, yy, Z, cmap=plt.cm.RdBu, alpha=0.5)
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.RdBu)
plt.xlim([-1.5, 3.5])
plt.ylim([-1.5, 1.5])

plt.show()

# %%
svm = SVC(kernel='rbf', gamma=100, C=100)

svm.fit(X, y)
xx, yy = np.meshgrid(np.linspace(-2, 3, 500),
                     np.linspace(-1.5, 2, 500))
Z = svm.decision_function(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)




plt.contourf(xx, yy, Z, cmap=plt.cm.RdBu, alpha=0.5)
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.RdBu)
plt.xlim([-1.5, 3.5])
plt.ylim([-1.5, 1.5])

plt.show()

# %%
svm = SVC(kernel='rbf', gamma=0.1, C=1.0)

svm.fit(X, y)
xx, yy = np.meshgrid(np.linspace(-2, 3, 500),
                     np.linspace(-1.5, 2, 500))
Z = svm.decision_function(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)




plt.contourf(xx, yy, Z, cmap=plt.cm.RdBu, alpha=0.5)
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.RdBu)
plt.xlim([-1.5, 3.5])
plt.ylim([-1.5, 1.5])

plt.show()

# %%
svm = SVC(kernel='rbf', gamma=1, C=1.0)

svm.fit(X, y)
xx, yy = np.meshgrid(np.linspace(-2, 3, 500),
                     np.linspace(-1.5, 2, 500))
Z = svm.decision_function(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)




plt.contourf(xx, yy, Z, cmap=plt.cm.RdBu, alpha=0.5)
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.RdBu)
plt.xlim([-1.5, 3.5])
plt.ylim([-1.5, 1.5])

plt.show()

# %%
svm = SVC(kernel='rbf', gamma=10, C=1.0)

svm.fit(X, y)
xx, yy = np.meshgrid(np.linspace(-2, 3, 500),
                     np.linspace(-1.5, 2, 500))
Z = svm.decision_function(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)




plt.contourf(xx, yy, Z, cmap=plt.cm.RdBu, alpha=0.5)
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.RdBu)
plt.xlim([-1.5, 3.5])
plt.ylim([-1.5, 1.5])

plt.show()

# %%
svm = SVC(kernel='rbf', gamma=100, C=1.0)

svm.fit(X, y)
xx, yy = np.meshgrid(np.linspace(-2, 3, 500),
                     np.linspace(-1.5, 2, 500))
Z = svm.decision_function(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)




plt.contourf(xx, yy, Z, cmap=plt.cm.RdBu, alpha=0.5)
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.RdBu)
plt.xlim([-1.5, 3.5])
plt.ylim([-1.5, 1.5])

plt.show()

# %%
svm = SVC(kernel='rbf', gamma=100, C=10)

svm.fit(X, y)
xx, yy = np.meshgrid(np.linspace(-2, 3, 500),
                     np.linspace(-1.5, 2, 500))
Z = svm.decision_function(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)




plt.contourf(xx, yy, Z, cmap=plt.cm.RdBu, alpha=0.5)
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.RdBu)
plt.xlim([-1.5, 3.5])
plt.ylim([-1.5, 1.5])

plt.show()

# %%
svm = SVC(kernel='rbf', gamma=100, C=100)

svm.fit(X, y)
xx, yy = np.meshgrid(np.linspace(-2, 3, 500),
                     np.linspace(-1.5, 2, 500))
Z = svm.decision_function(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)




plt.contourf(xx, yy, Z, cmap=plt.cm.RdBu, alpha=0.5)
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.RdBu)
plt.xlim([-1.5, 3.5])
plt.ylim([-1.5, 1.5])

plt.show()
